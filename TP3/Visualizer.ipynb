# %%
import matplotlib.pyplot as plt

# %%
epochs= []
trainAcc= []
f = open("accuracyTraining", "r")
for x in f:
    line = x.split(',')
    epochs.append(int(line[0]))
    acc= line[1].rstrip("\n")
    trainAcc.append(float(acc))

f.close()

# %%
testAc= []
f = open("accuracyTesting", "r")
for x in f:
    line = x.split(',')
    acc= line[1].rstrip("\n")
    testAc.append(float(acc))

f.close()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.plot(epochs, trainAcc, label = "Training")
plt.plot(epochs, testAc, label = "Testing")
plt.legend()

plt.show()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.plot(epochs[0:50], trainAcc[0:50], label = "Training")
plt.plot(epochs[0:50], testAc[0:50], label = "Testing")
plt.legend()

plt.show()

# %%
epochs= []
trainAcc= []
f = open("trainac", "r")
for x in f:
    line = x.split(',')
    epochs.append(int(line[0]))
    acc= line[1].rstrip("\n")
    trainAcc.append(float(acc))

f.close()

testAc= []
f = open("testac", "r")
for x in f:
    line = x.split(',')
    acc= line[1].rstrip("\n")
    testAc.append(float(acc))

f.close()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.plot(epochs, trainAcc, label = "Training")
plt.plot(epochs, testAc, label = "Testing")
plt.legend()

plt.show()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.plot(epochs[0:50], trainAcc[0:50], label = "Training")
plt.plot(epochs[0:50], testAc[0:50], label = "Testing")
plt.legend()

plt.show()
